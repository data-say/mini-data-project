# %% [markdown]
# # **쇼핑몰 주문 데이터 분석 - 고객 분석**

# %% [markdown]
# ### 데이터셋 소개
# - `CustomerInfo`: 주문 로그 데이터의 CustomerId를 기반으로 성별, 나이, 등록일, 등록기기 등을 랜덤 추출하여 만든 데이터

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('data/OnlineRetail2.csv')
data.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country  InvoiceHour  \
# 0  2010-12-01 08:26:00       2.55       17850  United Kingdom            8
# 1  2010-12-01 08:26:00       3.39       17850  United Kingdom            8
# 2  2010-12-01 08:26:00       2.75       17850  United Kingdom            8
# 3  2010-12-01 08:26:00       3.39       17850  United Kingdom            8
# 4  2010-12-01 08:26:00       3.39       17850  United Kingdom            8
#
#   InvoiceWeekday  InvoiceDay  InvoiceMonth  InvoiceYear  Amount
# ...

# %%
customer = pd.read_csv('data/CustomerInfo.csv')
customer.head()
# Out:
#    Unnamed: 0  customerid  age register_date register_device sex
# 0           0     17850.0    9    2010-11-25              sp   M
# 1           1     13047.0   10    2010-11-26             app   M
# 2           2     12583.0   30    2010-11-27              sp   M
# 3           3     13748.0   35    2010-11-28              pc   F
# 4           4     15100.0   50    2010-11-29              pc   F

# %%
customer.drop(['Unnamed: 0'], axis = 1, inplace = True)
customer.head()
# Out:
#    customerid  age register_date register_device sex
# 0     17850.0    9    2010-11-25              sp   M
# 1     13047.0   10    2010-11-26             app   M
# 2     12583.0   30    2010-11-27              sp   M
# 3     13748.0   35    2010-11-28              pc   F
# 4     15100.0   50    2010-11-29              pc   F
